# %% [markdown]
# # Building a Simple GIS with Yelp API and Folium - Lab
#
# ## Introduction
#
# So we have learned quite a bit about APIs and how they are now big buzzword in the tech industry. Think of it as a protocol for how to make requests and communicate with another server. We have seen how to mine Twitter for getting text data and apply basic frequency based NLP techniques to get some insight.
#
# One of the key aspects of being a data scientist is the ability to learn how a new API works, how to go through its specific authentication process (OAuth) and how to process the data structures that get returned as a response to our requests. It is a good practice to spend some time learning the API through the official documentation before sending in requests.
#
# On these lines, this lab requires you to learn another popular API (YELP Fusion) by following the provided detailed online documentation. We shall build a simple Geographical Information System (GIS) using the data from yelp.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Successfully sign up for Yelp API
# * Create HTTP requests to get data from Yelp API
# * Parse HTTP responses and perform data analysis on the data returned
# * Create a simple geographical system on to view information about selected businesses, at a given location.

# %% [markdown]
# ## The Yelp Fusion API - v3
#
#
# ### Point your browser over to this [yelp page](https://www.yelp.com/developers/v3/manage_app) and create an app in order to obtain  `client_id` and `api_key` tokens.
#
# **NOTE:** You will be required to sign up using Google or Facebook etc. if you dont already have an account.
#
# <img src="yelp_app.png" width=500>

# %% [markdown]
# After registration, you'll be presented with your account information and limits of your access. For Yelp, or any other API for that reason, you need to make sure that you dont surpass your request quota, otherwise, you may end up getting banned in some cases. Yelp shows this information to you as below:
#
# <img src="quota.png" width=500>

# %% [markdown]
# ### Save your api_key and client_id in the variables below:

# %%
# Save your tokens in the following string variables
client_id = 'daXmVQtyzQNoOXYDAOOHmQ'
api_key = 'LG5IBlecRe_ov7wtZtD_fvYZb621Tljkcox4_N3BOtF-ONNLmXHkd5BhOXMPvS04GHUEYs6t1jhvGIDjWVwshSCOJurZJSJpjIvTxyzQttKOGF6a_FwLFHzpl9MmXHYx'

# %% [markdown]
# ## The `yelpapi`

# %% [markdown]
# The yelpapi is a pure Python implementation of the Yelp Fusion API (aka Yelp v3 API). It is simple, fast, and robust to any changes Yelp may make to the API in the future. See tha basic usage of this library on the [official Github repo](https://github.com/gfairchild/yelpapi). You may look out for other APIs to achieve this but for this lesson, we shall use it for sake of simplicity.
#
# First you must pip install the library

# %%
# !pip install yelpapi
# Out:
# Requirement already satisfied: yelpapi in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (2.3.0)
# Requirement already satisfied: requests in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (from yelpapi) (2.19.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (from requests->yelpapi) (3.0.4)
# Requirement already satisfied: idna<2.8,>=2.5 in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (from requests->yelpapi) (2.7)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (from requests->yelpapi) (1.23)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (from requests->yelpapi) (2018.8.24)

# %% [markdown]
# ### Import `yelpapi ` into working environment and pass in the api_key as shown in the Github Repo

# %%
from yelpapi import YelpAPI
yelp_api = YelpAPI(api_key)

# %% [markdown]
# ### The Api request and response
#
# Great so we can now start making API calls using the format:
# ```python
# response = yelp_api.search_query(term =<search term>,
#                                  location=<search location>,
#                                  sort_by='rating',
#                                  limit=50)
# ```
# We can pass in a lot more arguments to refine our search. [Here is a complete list of options that search API provides us](https://www.yelp.com/developers/documentation/v3/business_search)
#
# * Make an API request using a simple criteria location and term
# * save the response as `response`
# * inspect the type and contents of `response`.

# %%
## Pass in a spcific term and location to make a call. 

response = yelp_api.search_query(term ='Ramen',
                                 location='New York', 
                                 sort_by='rating', 
                                 limit=50)

# For this example, we are looking for chinese food in London.
term = 'Chinese food'
location = 'London'
response
# Out:
# {'businesses': [{'id': 'VaDcSFv8Ir6lZely4BhPOw',
#    'alias': 'shinshi-ramen-new-york',
#    'name': 'Shinshi Ramen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/igCloMb68SW2cphCWBPPAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shinshi-ramen-new-york?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 171,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75732, 'longitude': -73.96791},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '235 E 53rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['235 E 53rd St', 'New York, NY 10022']},
#    'phone': '+16466697812',
#    'display_phone': '(646) 669-7812',
#    'distance': 6179.107838130476},
#   {'id': 'FlZ1zdVEKWv7dwqm8Uw8-w',
#    'alias': 'raku-new-york-7',
#    'name': 'Raku',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GEbZnH1jR4n7D5WOJ3urPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raku-new-york-7?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 791,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7264988089246,
#     'longitude': -73.9866526052356},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '342 E 6th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['342 E 6th St', 'New York, NY 10003']},
#    'phone': '+12122281324',
#    'display_phone': '(212) 228-1324',
#    'distance': 2428.0392489129867},
#   {'id': 'PBowYD8-vzqbv4yx0TilVg',
#    'alias': 'ramen-shack-long-island-city-3',
#    'name': 'Ramen Shack',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Q1CgHQ7_0zNupaNp6yRpRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ramen-shack-long-island-city-3?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 224,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7554119, 'longitude': -73.9414266},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '13-13 40th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['13-13 40th Ave', 'Long Island City, NY 11101']},
#    'phone': '+19295220285',
#    'display_phone': '(929) 522-0285',
#    'distance': 7121.367420026145},
#   {'id': 'ct58a_D8Z8DoJt7luB50wQ',
#    'alias': 'ramen-ishida-new-york',
#    'name': 'Ramen Ishida',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ppd71DnNkBxgNa-vVmBUow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ramen-ishida-new-york?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 110,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71959, 'longitude': -73.98834},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '122 Ludlow St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['122 Ludlow St', 'New York, NY 10002']},
#    'phone': '+16465903276',
#    'display_phone': '(646) 590-3276',
#    'distance': 1654.8796589730528},
#   {'id': '0vg2Z-HPwkyVVX613j2ysg',
#    'alias': 'pengs-noodle-folk-new-york-2',
#    'name': "Peng's Noodle Folk",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3hssUzkkn6YQORnam2QyBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pengs-noodle-folk-new-york-2?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 335,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77726, 'longitude': -73.94932},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1659 1st Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1659 1st Ave', 'New York, NY 10028']},
#    'phone': '+12123482878',
#    'display_phone': '(212) 348-2878',
#    'distance': 8842.376195907062},
#   {'id': 'C69uTzoWFaIWcpnYf2LbRw',
#    'alias': 'rokc-new-york',
#    'name': 'ROKC',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yLj7tmp7kDAzSnaEmwqi8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rokc-new-york?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 320,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.8235051, 'longitude': -73.9522425},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3452 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10031',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3452 Broadway', 'New York, NY 10031']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 13603.660951041153},
#   {'id': 's2ii7iNxb0-hGVxHf0yexw',
#    'alias': 'menkoi-sato-new-york-2',
#    'name': 'Menkoi Sato',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/13dseD01RSvknsRF_usErw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/menkoi-sato-new-york-2?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 88,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7316536618558,
#     'longitude': -74.0017022376845},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '7 Cornelia St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7 Cornelia St', 'New York, NY 10014']},
#    'phone': '+12127271050',
#    'display_phone': '(212) 727-1050',
#    'distance': 2980.4243672013704},
#   {'id': 'G9SWgxH65OBQaJaE8dHkbw',
#    'alias': 'zest-ramen-new-york-8',
#    'name': 'Zest Ramen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Lf5KNA9kkhK0poE6n_Zaog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zest-ramen-new-york-8?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 141,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'raw_food', 'title': 'Live/Raw Food'},
#     {'alias': 'izakaya', 'title': 'Izakaya'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71816, 'longitude': -73.99186},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '112 Eldridge St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['112 Eldridge St', 'New York, NY 10002']},
#    'phone': '+12122262801',
#    'display_phone': '(212) 226-2801',
#    'distance': 1426.6817316968902},
#   {'id': 'XKDHsS8PevoEdFLNtt05FA',
#    'alias': 'shuya-cafe-de-ramen-astoria',
#    'name': 'Shuya Cafe de Ramen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lm_uDGI-2qeR9IDdRKjjSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shuya-cafe-de-ramen-astoria?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 209,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.758007205736,
#     'longitude': -73.9167939666258},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '42-13 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42-13 Broadway', 'Astoria, NY 11103']},
#    'phone': '+17187770430',
#    'display_phone': '(718) 777-0430',
#    'distance': 8763.703476621678},
#   {'id': 'mESab-FqL5QqSVsnX72asQ',
#    'alias': 'zen-ramen-and-sushi-new-york',
#    'name': 'Zen Ramen & Sushi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-W7fV5FcFuq-KGw_IT_fow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zen-ramen-and-sushi-new-york?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 794,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.751743, 'longitude': -73.98899},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '150 W 36 street',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['150 W 36 street', 'New York, NY 10018']},
#    'phone': '+16468707509',
#    'display_phone': '(646) 870-7509',
#    'distance': 5173.256675208982},
#   {'id': 'r6r-XK_wL02FQdAgaauTxg',
#    'alias': 'kame-ramen-new-york-2',
#    'name': 'Kame Ramen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9ii2M4_3hWJaWn4B03G6Bg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kame-ramen-new-york-2?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 321,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74422, 'longitude': -73.9831},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '435 Park Ave S',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['435 Park Ave S', 'New York, NY 10016']},
#    'phone': '+12126448989',
#    'display_phone': '(212) 644-8989',
#    'distance': 4415.407188565314},
#   {'id': '7xpbioe88rnW7JjzLEQeRg',
#    'alias': 'samurai-papa-brooklyn-2',
#    'name': 'Samurai Papa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9zhXHJ1j6hQ-9GltTze6wg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/samurai-papa-brooklyn-2?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 235,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.702892072912, 'longitude': -73.943588398397},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '32 Varet St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32 Varet St', 'Brooklyn, NY 11206']},
#    'phone': '+17185997171',
#    'display_phone': '(718) 599-7171',
#    'distance': 4283.594049624182},
#   {'id': 'OFfZUS-nu6NDnsWe1B2bUQ',
#    'alias': 'tonchin-new-york-new-york',
#    'name': 'TONCHIN NEW YORK',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EA5igkg5gxqHxDcM4YA6hA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tonchin-new-york-new-york?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 560,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'izakaya', 'title': 'Izakaya'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7502727, 'longitude': -73.9844951},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '13 W 36th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['13 W 36th St', 'New York, NY 10018']},
#    'phone': '+16466929912',
#    'display_phone': '(646) 692-9912',
#    'distance': 5052.538311265594},
#   {'id': 'dgU5NoylJVJ5rDZY_PezkA',
#    'alias': 'blackbeard-ramen-cliffside-park-2',
#    'name': 'Blackbeard Ramen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nOpJ3Lu9buSeuvMk54G8Iw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blackbeard-ramen-cliffside-park-2?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 425,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.8243714, 'longitude': -73.9877499},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '607 Gorge Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Cliffside Park',
#     'zip_code': '07010',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['607 Gorge Rd', 'Cliffside Park, NJ 07010']},
#    'phone': '+12019438003',
#    'display_phone': '(201) 943-8003',
#    'distance': 13235.48969843827},
#   {'id': 'oy_FqW6XO8S06pg6nHbhog',
#    'alias': 'ramen-hood-new-york',
#    'name': 'Ramen Hood',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/U14n3BQ2YlX3lZDQ97xsTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ramen-hood-new-york?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 72,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7223112701284,
#     'longitude': -73.9973774072879},
#    'transactions': [],
#    'location': {'address1': '62 Spring St',
#     'address2': "Chef's Club Counter",
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['62 Spring St',
#      "Chef's Club Counter",
#      'New York, NY 10012']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1893.3856522672554},
#   {'id': 'ya4nQkuVH1ZnmNp9m1yISg',
#    'alias': 'tatsu-ramen-new-york',
#    'name': 'Tatsu Ramen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/noflx3CUjyJf9uTCv8zFAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tatsu-ramen-new-york?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 174,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72908, 'longitude': -73.98446},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '167 1st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['167 1st Ave', 'New York, NY 10003']},
#    'phone': '+19292847088',
#    'display_phone': '(929) 284-7088',
#    'distance': 2754.6986940765037},
#   {'id': 'xrnk8mgoV7up6fauVmugpw',
#    'alias': 'jun-men-ramen-bar-new-york',
#    'name': 'Jun-Men Ramen Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EcsM2oQX8f0UL1miJO3rFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jun-men-ramen-bar-new-york?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 538,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.748209, 'longitude': -74.00047},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '249 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['249 9th Ave', 'New York, NY 10001']},
#    'phone': '+16468526787',
#    'display_phone': '(646) 852-6787',
#    'distance': 4783.5515357451095},
#   {'id': '44SY464xDHbvOcjDzRbKkQ',
#    'alias': 'ippudo-ny-new-york-7',
#    'name': 'Ippudo NY',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zF3EgqHCk7zBUwD2B3WTEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ippudo-ny-new-york-7?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 9597,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73092, 'longitude': -73.99015},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '65 4th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['65 4th Ave', 'New York, NY 10003']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2855.84485141638},
#   {'id': 'TN4RnyqHMSupRFot4Q-_EA',
#    'alias': 'ippudo-westside-new-york',
#    'name': 'Ippudo Westside',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EmJBZo1FvHemEBgyJknEOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ippudo-westside-new-york?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 3339,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76344, 'longitude': -73.98661},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '321 W 51st St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['321 W 51st St', 'New York, NY 10019']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6486.789308886469},
#   {'id': 'L3reOLLPez7lnOhyfCpvkg',
#    'alias': 'shinka-ramen-and-sake-bar-new-york-3',
#    'name': 'Shinka Ramen & Sake Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Z079skdfDKUYwx_MCiO_Ag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shinka-ramen-and-sake-bar-new-york-3?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 159,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7170795322745,
#     'longitude': -73.9952574670315},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '93 Bowery St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['93 Bowery St', 'New York, NY 10002']},
#    'phone': '+12123438111',
#    'display_phone': '(212) 343-8111',
#    'distance': 1296.2649586643338},
#   {'id': 'icpLRhJ1jpBX1zBGkt7Xqg',
#    'alias': 'teppen-ramen-new-york-2',
#    'name': 'Teppen Ramen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/N8JKcU67M1Udd7nA-HVjzQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/teppen-ramen-new-york-2?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 217,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75929, 'longitude': -73.96879},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '159 E 55th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['159 E 55th St', 'New York, NY 10022']},
#    'phone': '+12123552974',
#    'display_phone': '(212) 355-2974',
#    'distance': 6358.249987329688},
#   {'id': 'wWmVAc4NnB3q0onYRM-RkA',
#    'alias': 'zundo-ya-new-york',
#    'name': 'Zundo-Ya',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/z-e1xeCjk2YBJxxgFkuM8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zundo-ya-new-york?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 657,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7308616638184,
#     'longitude': -73.9899444580078},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '84 E 10th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['84 E 10th St', 'New York, NY 10003']},
#    'phone': '+19176393549',
#    'display_phone': '(917) 639-3549',
#    'distance': 2850.332327159626},
#   {'id': 'W2Dj_3C2ySoXgg1SaGVj6g',
#    'alias': 'nippon-cha-bayside-2',
#    'name': 'Nippon Cha',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nhXutDGvHFqMQkgIGRbeFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nippon-cha-bayside-2?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 614,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76432, 'longitude': -73.77167},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '39-34 Bell Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Bayside',
#     'zip_code': '11361',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39-34 Bell Blvd', 'Bayside, NY 11361']},
#    'phone': '+17182290805',
#    'display_phone': '(718) 229-0805',
#    'distance': 19866.426303435404},
#   {'id': 'yFnvBuOaMVy6_HqCnUl1Tg',
#    'alias': 'tairyo-japanese-fusion-brooklyn',
#    'name': 'Tairyo Japanese Fusion',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JDfW0NOUEJtybkdN3fYqbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tairyo-japanese-fusion-brooklyn?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 27,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.63186, 'longitude': -74.0274699},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '7407 3rd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7407 3rd Ave', 'Brooklyn, NY 11209']},
#    'phone': '+17188668090',
#    'display_phone': '(718) 866-8090',
#    'distance': 8647.441431619078},
#   {'id': 'i-s1bcKdqQdm6JiVN0JRMA',
#    'alias': 'yokoya-new-york-5',
#    'name': 'Yokoya',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oqvNlhgb4Jm_QSnITKAj7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yokoya-new-york-5?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 165,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72254, 'longitude': -73.98917},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '201 Allen St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['201 Allen St', 'New York, NY 10002']},
#    'phone': '+12123881388',
#    'display_phone': '(212) 388-1388',
#    'distance': 1948.9603436057032},
#   {'id': 'oTkzgr7hzOAdlP99Auj3GQ',
#    'alias': 'momosan-ramen-and-sake-new-york-2',
#    'name': 'Momosan Ramen & Sake',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Z6hFFtvLlEIf5SqwxckvmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/momosan-ramen-and-sake-new-york-2?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 1361,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74993, 'longitude': -73.97746},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '342 Lexington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['342 Lexington Ave', 'New York, NY 10016']},
#    'phone': '+16462015529',
#    'display_phone': '(646) 201-5529',
#    'distance': 5145.797928492699},
#   {'id': 'WLl0nKeWBksVM5SkKKuLpg',
#    'alias': 'tabetomo-new-york',
#    'name': 'TabeTomo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-nXfARq1RBtTtEMCIQ0_dQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tabetomo-new-york?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 61,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72688, 'longitude': -73.98311},
#    'transactions': [],
#    'location': {'address1': '131 Avenue A',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['131 Avenue A', 'New York, NY 10009']},
#    'phone': '+16468506414',
#    'display_phone': '(646) 850-6414',
#    'distance': 2569.588273134286},
#   {'id': 'O9WmKufAUqDM0j2HpgLVlw',
#    'alias': 'tamashii-ramen-astoria',
#    'name': 'Tamashii Ramen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bKRkhNRxrNhH-EdNxbNwRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tamashii-ramen-astoria?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 630,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7628026, 'longitude': -73.926578},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2905 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2905 Broadway', 'Astoria, NY 11106']},
#    'phone': '+17182785888',
#    'display_phone': '(718) 278-5888',
#    'distance': 8557.463872432614},
#   {'id': '9jRwUN3z7k0seLOzWERVeg',
#    'alias': 'ramen-ya-new-york-5',
#    'name': 'Ramen-Ya',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3ZkE8aW7z1MMT_OD5hVmFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ramen-ya-new-york-5?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 875,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.732536, 'longitude': -74.001681},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '181 W 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['181 W 4th St', 'New York, NY 10014']},
#    'phone': '+12129895440',
#    'display_phone': '(212) 989-5440',
#    'distance': 3076.0635234885613},
#   {'id': 'af_i3fBov6BCMSfp5rrAdg',
#    'alias': 'ramen-lab-new-york-2',
#    'name': 'Ramen Lab',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AaKkltKN5ylrazNG7eSqPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ramen-lab-new-york-2?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 294,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7209918, 'longitude': -73.9963582},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '70 Kenmare St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['70 Kenmare St', 'New York, NY 10012']},
#    'phone': '+16466137522',
#    'display_phone': '(646) 613-7522',
#    'distance': 1737.4775665439095},
#   {'id': '-134ZvJ4lgiqx-sjRBWQ9g',
#    'alias': 'totto-ramen-new-york-12',
#    'name': 'Totto Ramen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Y8osWRRtc_X1mqAXkvIFKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/totto-ramen-new-york-12?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 5046,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7643285462369,
#     'longitude': -73.9876558773155},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '366 W 52nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['366 W 52nd St', 'New York, NY 10019']},
#    'phone': '+12125820052',
#    'display_phone': '(212) 582-0052',
#    'distance': 6571.398754527679},
#   {'id': 'j-a8HUcsBJXHV2IfF786jw',
#    'alias': 'kogane-ramen-brooklyn-heights',
#    'name': 'Kogane Ramen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nCavIzqgP6sGG5Sitq_MCg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kogane-ramen-brooklyn-heights?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 275,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.698608, 'longitude': -73.992675},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '76 Henry St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn Heights',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['76 Henry St', 'Brooklyn Heights, NY 11201']},
#    'phone': '+17188752828',
#    'display_phone': '(718) 875-2828',
#    'distance': 770.8437319673892},
#   {'id': '9dikwBwukRl26W6Jqo09nQ',
#    'alias': 'oramen-new-york-2',
#    'name': 'Oramen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6u8dtD_WO_8rR2ucSW4Kdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oramen-new-york-2?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 217,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7390256, 'longitude': -73.9960282},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '579 6th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['579 6th Ave', 'New York, NY 10011']},
#    'phone': '+16469985754',
#    'display_phone': '(646) 998-5754',
#    'distance': 3736.8647780359456},
#   {'id': 'eS9mTLlWwu_Ap2ROMQWPxg',
#    'alias': 'chuko-brooklyn-2',
#    'name': 'Chuko',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AH6y2pp9yS_36BMoqr5dbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chuko-brooklyn-2?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 1004,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.680784, 'longitude': -73.967455},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '565 Vanderbilt Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['565 Vanderbilt Ave', 'Brooklyn, NY 11238']},
#    'phone': '+13474259570',
#    'display_phone': '(347) 425-9570',
#    'distance': 3555.179777356736},
#   {'id': '7lv8jYYurEBFRglhPYALkw',
#    'alias': 'tampopo-ramen-new-york',
#    'name': 'Tampopo Ramen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EOoVXDWqNeVouY_hjwOeMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tampopo-ramen-new-york?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 309,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.850719, 'longitude': -73.936309},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1 Bennett Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10033',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Bennett Ave', 'New York, NY 10033']},
#    'phone': '+12129230575',
#    'display_phone': '(212) 923-0575',
#    'distance': 16879.280912998864},
#   {'id': 'D65eObUbArHu6UiQsUasgw',
#    'alias': 'hinomaru-ramen-astoria-2',
#    'name': 'HinoMaru Ramen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/eRbOdXYqfYazQuy1QoSE1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hinomaru-ramen-astoria-2?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 775,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.774889916651,
#     'longitude': -73.9092001318932},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '33-18 Ditmars Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33-18 Ditmars Blvd', 'Astoria, NY 11105']},
#    'phone': '+17187770228',
#    'display_phone': '(718) 777-0228',
#    'distance': 10536.779925777992},
#   {'id': '9bAyxRD6RsGEUQw424ovQA',
#    'alias': 'nishida-sho-ten-new-york-2',
#    'name': 'Nishida Sho-ten',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jQRPcnfWj9TiA0wYX3ZJbw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nishida-sho-ten-new-york-2?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 671,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.753969, 'longitude': -73.968722},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '302 E 49th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['302 E 49th St', 'New York, NY 10017']},
#    'phone': '+12123080791',
#    'display_phone': '(212) 308-0791',
#    'distance': 5809.9571815058325},
#   {'id': 'raelHbSJ_gTo701c-KyXWg',
#    'alias': 'minca-new-york',
#    'name': 'Minca',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FA5RXCUnc-djMSF-0xWNmg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/minca-new-york?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 1586,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72412, 'longitude': -73.98288},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '536 E 5th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['536 E 5th St', 'New York, NY 10009']},
#    'phone': '+12125058001',
#    'display_phone': '(212) 505-8001',
#    'distance': 2273.800952319139},
#   {'id': 'UTLEGU4mLmB26DiX99Ggxw',
#    'alias': 'tamashii-blue-long-island-city',
#    'name': 'Tamashii Blue',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lQOgpZF-7xXpboSU6lUR4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tamashii-blue-long-island-city?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 220,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74452, 'longitude': -73.9538},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '47-36 Vernon Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47-36 Vernon Blvd', 'Long Island City, NY 11101']},
#    'phone': '+17184722142',
#    'display_phone': '(718) 472-2142',
#    'distance': 5524.7451459377},
#   {'id': 'Pfjb9Rn5Th7R-pLXVARwlA',
#    'alias': 'jin-ramen-west-harlem-new-york',
#    'name': 'Jin Ramen - West Harlem',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6gZdziyVJ2P8kiqmDkWjng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jin-ramen-west-harlem-new-york?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 984,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8154774, 'longitude': -73.9587672},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '3183 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3183 Broadway', 'New York, NY 10027']},
#    'phone': '+16465592862',
#    'display_phone': '(646) 559-2862',
#    'distance': 12595.605267146446},
#   {'id': 'EvAJBgBdgOt1jx1EufRN7w',
#    'alias': 'jin-ramen-new-york-3',
#    'name': 'Jin Ramen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xHJbolUgTh-MTlc0qHOmww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jin-ramen-new-york-3?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 723,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78534, 'longitude': -73.97695},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '462 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['462 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+16466570755',
#    'display_phone': '(646) 657-0755',
#    'distance': 9001.810120581258},
#   {'id': 'abNHO9-xlCsv31gghCUuxw',
#    'alias': 'zutto-japanese-american-pub-new-york-2',
#    'name': 'Zutto Japanese American Pub',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nBGNjJI_Sl4m6otaGEmxww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zutto-japanese-american-pub-new-york-2?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 836,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71847, 'longitude': -74.00903},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '77 Hudson St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['77 Hudson St', 'New York, NY 10013']},
#    'phone': '+12122333287',
#    'display_phone': '(212) 233-3287',
#    'distance': 1912.3268225904576},
#   {'id': 'hdiTkEnD14VpXNl-APTg2g',
#    'alias': 'nana-ramen-brooklyn',
#    'name': 'Nana Ramen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LXLGS9Go-Fh20inuHsxzsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nana-ramen-brooklyn?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 112,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6815479, 'longitude': -73.9289913},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '330 Malcolm X Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11233',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['330 Malcolm X Blvd', 'Brooklyn, NY 11233']},
#    'phone': '+19292100589',
#    'display_phone': '(929) 210-0589',
#    'distance': 6113.234995284128},
#   {'id': 'yckkW5iFRiBOWsH3tZTr3Q',
#    'alias': 'hashi-ramen-and-izakaya-flushing-4',
#    'name': 'Hashi Ramen & Izakaya',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nejIuF5kpK1g9YWtyqzGFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hashi-ramen-and-izakaya-flushing-4?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 1013,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7578101754189,
#     'longitude': -73.7891612201929},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '192-12 Northern Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11358',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['192-12 Northern Blvd', 'Flushing, NY 11358']},
#    'phone': '+17182242961',
#    'display_phone': '(718) 224-2961',
#    'distance': 18238.95344833164},
#   {'id': '5EaTaKHxXtD5bTCVnbi2Xw',
#    'alias': 'za-ya-ramen-brooklyn',
#    'name': 'Za-Ya Ramen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HUCXBbsrcKakrbugZGagBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/za-ya-ramen-brooklyn?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 105,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6741699, 'longitude': -73.99968},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '545 Court St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['545 Court St', 'Brooklyn, NY 11231']},
#    'phone': '+13479874103',
#    'display_phone': '(347) 987-4103',
#    'distance': 3510.4225016735527},
#   {'id': 'v3qQvMjj4KSZ4dPU4ERyiw',
#    'alias': 'ramen-spot-brooklyn-4',
#    'name': 'Ramen Spot',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xj3ctOgKFjIwEACzDS6W6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ramen-spot-brooklyn-4?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 35,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7268634, 'longitude': -73.952345},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '760 Manhattan Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['760 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17188092527',
#    'display_phone': '(718) 809-2527',
#    'distance': 4262.772037294635},
#   {'id': 'e-G1yC5u8LOcQ-fx0Lxthw',
#    'alias': 'ajihei-bushwick-brooklyn',
#    'name': 'Ajihei Bushwick',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ip2qTTy7v9gbVNxIlEMSzQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ajihei-bushwick-brooklyn?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 54,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70416, 'longitude': -73.92799},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '156 Knickerbocker Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['156 Knickerbocker Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17185522065',
#    'display_phone': '(718) 552-2065',
#    'distance': 5588.86544590715},
#   {'id': 'W5RSIwNKBa7k0jeAs5KDYg',
#    'alias': 'mei-jin-ramen-new-york',
#    'name': 'Mei Jin Ramen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OjfhYz-Jq53RcjTzkvU2Qg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mei-jin-ramen-new-york?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 570,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.775028, 'longitude': -73.953491},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1574 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1574 2nd Ave', 'New York, NY 10028']},
#    'phone': '+12123272800',
#    'display_phone': '(212) 327-2800',
#    'distance': 8465.927287551587},
#   {'id': 'z_yu_Qo1xTLeYPBqBM5igA',
#    'alias': 'menya-jiro-fidi-new-york',
#    'name': 'Menya Jiro- Fidi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/a4LRwkhczd3f5_IVgmln3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/menya-jiro-fidi-new-york?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 119,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70933, 'longitude': -74.00714},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '123 William St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['123 William St', 'New York, NY 10038']},
#    'phone': '+16469461616',
#    'display_phone': '(646) 946-1616',
#    'distance': 1183.3226218346988},
#   {'id': 'nhez4xxvwwYIQEN2Vrj9mQ',
#    'alias': 'yuji-ramen-brooklyn-3',
#    'name': 'YUJI Ramen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/meZkOUiyswxYOlh2-lOQoA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yuji-ramen-brooklyn-3?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 115,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.712527, 'longitude': -73.9487788},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '150 Ainslie St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['150 Ainslie St', 'Brooklyn, NY 11211']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3916.365753831747}],
#  'total': 1800,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
# Make an API call using chosen term and location

response = yelp_api.search_query(term =term,
                                 location=location, 
                                 sort_by='rating', 
                                 limit=50)
type(response)
print(response)
# Out:
# {'businesses': [{'id': 'h2cCoDNQOPd51HFwvuAGNg', 'alias': 'hakkasan-london-3', 'name': 'Hakkasan', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IcS9yzJnweDO4DsfJ94jAw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/hakkasan-london-3?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ', 'review_count': 218, 'categories': [{'alias': 'cantonese', 'title': 'Cantonese'}], 'rating': 4.0, 'coordinates': {'latitude': 51.5171482803943, 'longitude': -0.13180578932657}, 'transactions': [], 'price': '££££', 'location': {'address1': '8 Hanway Place', 'address2': '', 'address3': '', 'city': 'London', 'zip_code': 'W1T 1HD', 'country': 'GB', 'state': 'XGL', 'display_address': ['8 Hanway Place', 'London W1T 1HD', 'United Kingdom']}, 'phone': '+442079277000', 'display_phone': '+44 20 7927 7000', 'distance': 558.9650039747677}, {'id': 'QE5aa5N-dbfvafLsjn7TVg', 'alias': 'bamboo-flute-fitzrovia', 'name': 'Bamboo Flute', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kYQZjHmzt8zy1634OsAsxQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/bamboo-flute-fitzrovia?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ', 'review_count': 28, 'categories': [{'alias': 'chinese', 'title': 'Chinese'}], 'rating': 4.5, 'coordinates': {'latitude': 51.5228746, 'longitude': -0.1418939}, 'transactions': [], 'price': '£', 'location': {'address1': '145 Cleveland Street', 'address2': '', 'address3': '', 'city': 'Fitzrovia', 'zip_code': 'W1T 6QH', 'country': 'GB', 'state': 'XGL', 'display_address': ['145 Cleveland Street', 'Fitzrovia W1T 6QH', 'United Kingdom']}, 'phone': '+442073872738', 'display_phone': '+44 20 7387 2738', 'distance': 1189.5082547156321}, {'id': 'sYwBQ7mJYhB35nn-_SZstQ', 'alias': 'yauatcha-london-7', 'name': 'Yauatcha', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/G7Ydt9lmtWsUN1gRhlCRsw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/yauatcha-london-7?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ', 'review_count': 456, 'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'noodles', 'title': 'Noodles'}], 'rating': 4.0, 'coordinates': {'latitude': 51.5137076071076, 'longitude': -0.135128831605189}, 'transactions': [], 'price': '£££', 'location': {'address1': '15-17 Broadwick Street', 'address2': '', 'address3': '', 'city': 'London', 'zip_code': 'W1F 0DL', 'country': 'GB', 'state': 'XGL', 'display_address': ['15-17 Broadwick Street', 'London W1F 0DL', 'United Kingdom']}, 'phone': '+442074948888', 'display_phone': '+44 20 7494 8888', 'distance': 112.59840998419494}, {'id': 'pdFiFtol9YI__9ROOXUIYA', 'alias': 'lanzhou-noodle-bar-london', 'name': 'Lanzhou Noodle Bar', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IKy91e7hb9w14m4eA9HH1w/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/lanzhou-noodle-bar-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ', 'review_count': 310, 'categories': [{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'noodles', 'title': 'Noodles'}], 'rating': 4.0, 'coordinates': {'latitude': 51.5116034713013, 'longitude': -0.127834377873126}, 'transactions': [], 'price': '£', 'location': {'address1': '33 Cranbourne Street', 'address2': '', 'address3': '', 'city': 'London', 'zip_code': 'WC2H 7AD', 'country': 'GB', 'state': 'XGL', 'display_address': ['33 Cranbourne Street', 'London WC2H 7AD', 'United Kingdom']}, 'phone': '+442074674546', 'display_phone': '+44 20 7467 4546', 'distance': 578.4743547816091}, {'id': 'chEEcQbc8PbidTeXK34H9g', 'alias': 'hakkasan-mayfair-london-2', 'name': 'Hakkasan Mayfair', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LX_W20RxnR5yzB3dTN6 ...

# %% [markdown]
# ### JSON .. again !
#
# We have a nice nifty little return now! As you can see, the contents of the response is formatted as a string but what kind of data structures does this remind you of?
#
# To start there's the outer curly brackets:
#
# #### {"businesses":
#
# Hopefully you're thinking 'hey that's just like a python dictionary!'
#
# Then within that we have what appears to be a list of dictionaries:
#
# #### {"id": "jeWIYbgBho9vBDhc5S1xvg",
#
# This response is an example of a JSON (JavaScript Object Notation) format that we've seen so many times before. We can simply treat it as a dictionary and process it further.

# %% [markdown]
# ### Inspect the values for all the keys in the response

# %%
# inspect the key value pairs to understand the strcuture of data 
response
# Out:
# {'businesses': [{'id': 'h2cCoDNQOPd51HFwvuAGNg',
#    'alias': 'hakkasan-london-3',
#    'name': 'Hakkasan',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IcS9yzJnweDO4DsfJ94jAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hakkasan-london-3?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 218,
#    'categories': [{'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5171482803943,
#     'longitude': -0.13180578932657},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '8 Hanway Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 1HD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Hanway Place', 'London W1T 1HD', 'United Kingdom']},
#    'phone': '+442079277000',
#    'display_phone': '+44 20 7927 7000',
#    'distance': 558.9650039747677},
#   {'id': 'QE5aa5N-dbfvafLsjn7TVg',
#    'alias': 'bamboo-flute-fitzrovia',
#    'name': 'Bamboo Flute',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kYQZjHmzt8zy1634OsAsxQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bamboo-flute-fitzrovia?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 28,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5228746, 'longitude': -0.1418939},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '145 Cleveland Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Fitzrovia',
#     'zip_code': 'W1T 6QH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['145 Cleveland Street',
#      'Fitzrovia W1T 6QH',
#      'United Kingdom']},
#    'phone': '+442073872738',
#    'display_phone': '+44 20 7387 2738',
#    'distance': 1189.5082547156321},
#   {'id': 'sYwBQ7mJYhB35nn-_SZstQ',
#    'alias': 'yauatcha-london-7',
#    'name': 'Yauatcha',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/G7Ydt9lmtWsUN1gRhlCRsw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yauatcha-london-7?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 456,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5137076071076,
#     'longitude': -0.135128831605189},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '15-17 Broadwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0DL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15-17 Broadwick Street',
#      'London W1F 0DL',
#      'United Kingdom']},
#    'phone': '+442074948888',
#    'display_phone': '+44 20 7494 8888',
#    'distance': 112.59840998419494},
#   {'id': 'pdFiFtol9YI__9ROOXUIYA',
#    'alias': 'lanzhou-noodle-bar-london',
#    'name': 'Lanzhou Noodle Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IKy91e7hb9w14m4eA9HH1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lanzhou-noodle-bar-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 310,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5116034713013,
#     'longitude': -0.127834377873126},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '33 Cranbourne Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 7AD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['33 Cranbourne Street',
#      'London WC2H 7AD',
#      'United Kingdom']},
#    'phone': '+442074674546',
#    'display_phone': '+44 20 7467 4546',
#    'distance': 578.4743547816091},
#   {'id': 'chEEcQbc8PbidTeXK34H9g',
#    'alias': 'hakkasan-mayfair-london-2',
#    'name': 'Hakkasan Mayfair',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LX_W20RxnR5yzB3dTN6IdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hakkasan-mayfair-london-2?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 117,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5103202323384,
#     'longitude': -0.144935268434918},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '17 Bruton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 6QB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17 Bruton Street',
#      'London W1J 6QB',
#      'United Kingdom']},
#    'phone': '+442079071888',
#    'display_phone': '+44 20 7907 1888',
#    'distance': 681.4450716267161},
#   {'id': '6iCxFP7Oc0qG_6ByenO0sw',
#    'alias': 'silk-road-london-2',
#    'name': 'Silk Road',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pUXusTIbeDRInvi6fkNjmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/silk-road-london-2?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 43,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4739712, 'longitude': -0.0896081},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '49 Camberwell Church Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE5 8TR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['49 Camberwell Church Street',
#      'London SE5 8TR',
#      'United Kingdom']},
#    'phone': '+442077034832',
#    'display_phone': '+44 20 7703 4832',
#    'distance': 5403.445838977789},
#   {'id': 'Mrv3dA42EioqBz50t_f24Q',
#    'alias': 'hunan-london',
#    'name': 'Hunan',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sEgrRrMVkWaky7Yc7dvdgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hunan-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 38,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.490493, 'longitude': -0.1526547},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '51 Pimlico Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 8NE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['51 Pimlico Road',
#      'London SW1W 8NE',
#      'United Kingdom']},
#    'phone': '+442077305712',
#    'display_phone': '+44 20 7730 5712',
#    'distance': 2741.6022690860036},
#   {'id': 'MpdG-D0nKwGEZp0ApTtBaA',
#    'alias': 'barshu-london-2',
#    'name': 'Barshu',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jaGznOhEvqqcJXKCYt12Ug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barshu-london-2?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 96,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512835, 'longitude': -0.130857},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '28 Frith Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 5LF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['28 Frith Street',
#      'London W1D 5LF',
#      'United Kingdom']},
#    'phone': '+442072878822',
#    'display_phone': '+44 20 7287 8822',
#    'distance': 357.1885184880618},
#   {'id': '5-_YNjtvoG-oYt1qAO3tVw',
#    'alias': 'bugis-street-brasserie-london',
#    'name': 'Bugis Street Brasserie',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kgtAwZ3oF2wh05ndSzQ1zA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bugis-street-brasserie-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 44,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'singaporean', 'title': 'Singaporean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4936621211568,
#     'longitude': -0.183931280273902},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Millennium Hotels & Resorts',
#     'address2': '4-18 Harrington Gardens',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 4LH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Millennium Hotels & Resorts',
#      '4-18 Harrington Gardens',
#      'London SW7 4LH',
#      'United Kingdom']},
#    'phone': '+442073316211',
#    'display_phone': '+44 20 7331 6211',
#    'distance': 3946.1405823998143},
#   {'id': '3ea8x8r0gsVy8ltQycldsA',
#    'alias': 'gold-mine-london',
#    'name': 'Gold Mine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aihm1QdPS5Mq79T_9rP7tA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gold-mine-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 69,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5133018493652,
#     'longitude': -0.187491998076439},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '102 Queensway',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 3RR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['102 Queensway', 'London W2 3RR', 'United Kingdom']},
#    'phone': '+442077928331',
#    'display_phone': '+44 20 7792 8331',
#    'distance': 3571.4713192257427},
#   {'id': '2NdnxONuSAsDkQPhU919tQ',
#    'alias': 'royal-china-london-2',
#    'name': 'Royal China',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Mpn3L7JpUdeAJqG0d7Ub3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/royal-china-london-2?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 97,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5105005571439,
#     'longitude': -0.187244316153717},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '13 Queensway',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 4QJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 Queensway', 'London W2 4QJ', 'United Kingdom']},
#    'phone': '+442072212535',
#    'display_phone': '+44 20 7221 2535',
#    'distance': 3558.785103799373},
#   {'id': 'AwwZIdmScSHhM54Wh8P8JQ',
#    'alias': 'chi-noodle-london',
#    'name': 'Chi Noodle',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Wk6KBsJ4SWYtUSBDm1xljg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chi-noodle-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 29,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5135092, 'longitude': -0.1053698},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '5 New Bridge Street',
#     'address2': 'Bride Court',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'EC4V 6AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 New Bridge Street',
#      'Bride Court',
#      'London EC4V 6AB',
#      'United Kingdom']},
#    'phone': '+442073532409',
#    'display_phone': '+44 20 7353 2409',
#    'distance': 2117.888856995979},
#   {'id': 'aOSZ-xTyLrR2LX6-Wgf6OQ',
#    'alias': 'joy-king-lau-london',
#    'name': 'Joy King Lau',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/85gPvGR5sums1f0bdcy62g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joy-king-lau-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 131,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.511104, 'longitude': -0.13113},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '3 Leicester Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 7BL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Leicester Street',
#      'London WC2H 7BL',
#      'United Kingdom']},
#    'phone': '+442074371132',
#    'display_phone': '+44 20 7437 1132',
#    'distance': 385.48318993171404},
#   {'id': 'xriXls0Dn4ru2ODF6fDWhQ',
#    'alias': 'sichuan-folk-london',
#    'name': 'Sichuan Folk',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nb1TNrVfOvCpUW1pS_MVrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sichuan-folk-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 65,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.520178, 'longitude': -0.072425},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '32 Hanbury Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6QR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['32 Hanbury Street',
#      'London E1 6QR',
#      'United Kingdom']},
#    'phone': '+442072474735',
#    'display_phone': '+44 20 7247 4735',
#    'distance': 4471.20821766474},
#   {'id': 'Aar0fS6vSWRhQc7WddYagg',
#    'alias': 'xian-impressions-london',
#    'name': "Xi'an Impressions",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VDbI_euzpp8AfjMF2-ndIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/xian-impressions-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 27,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5539006581936,
#     'longitude': -0.110344699913454},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '117 Benwell Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N7 7BW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['117 Benwell Road',
#      'London N7 7BW',
#      'United Kingdom']},
#    'phone': '+442034410191',
#    'display_phone': '+44 20 3441 0191',
#    'distance': 4897.827262129786},
#   {'id': '3EZWvxhLjYEqAQyg1VJ9Zg',
#    'alias': 'dragon-castle-london',
#    'name': 'Dragon Castle',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qF_dr86TN3GIToGO6lhZFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dragon-castle-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 46,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.492101, 'longitude': -0.098573},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '100 Walworth Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE17 1JL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['100 Walworth Road',
#      'London SE17 1JL',
#      'United Kingdom']},
#    'phone': '+442072773388',
#    'display_phone': '+44 20 7277 3388',
#    'distance': 3484.935669306307},
#   {'id': 'vtFvSTgUW9KICwDGtnQSug',
#    'alias': 'canton-element-london',
#    'name': 'Canton Element',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MMHfsdoHDpCmigvBr6y9bA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/canton-element-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 11,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'karaoke', 'title': 'Karaoke'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.519862, 'longitude': -0.117582},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '48 Red Lion Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1R 4PF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['48 Red Lion Street',
#      'London WC1R 4PF',
#      'United Kingdom']},
#    'phone': '+442072421515',
#    'display_phone': '+44 20 7242 1515',
#    'distance': 1501.0470490724267},
#   {'id': '4wnP2JAuR92yoS3TybKyRA',
#    'alias': 'bun-house-london',
#    'name': 'Bun House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0pEoyRDbUPkPRs3D7wBS4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bun-house-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 29,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51365, 'longitude': -0.130452},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '23-24 Greek Street',
#     'address2': 'Soho',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1D 4DZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['23-24 Greek Street',
#      'Soho',
#      'London W1D 4DZ',
#      'United Kingdom']},
#    'phone': '+442080179888',
#    'display_phone': '+44 20 8017 9888',
#    'distance': 391.48496685335056},
#   {'id': 'hdp4iZf_iUmYzDrvHjblPw',
#    'alias': 'the-duck-and-rice-london',
#    'name': 'The Duck and Rice',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8JaqXM1qCqWTdqzIphfJ1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-duck-and-rice-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 57,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.513487, 'longitude': -0.135082},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '90 Berwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0QB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['90 Berwick Street',
#      'London W1F 0QB',
#      'United Kingdom']},
#    'phone': '+442033277888',
#    'display_phone': '+44 20 3327 7888',
#    'distance': 98.56398403934607},
#   {'id': 'heTzmXTNQeuXvVhdpFJwaA',
#    'alias': 'princess-garden-of-mayfair-london',
#    'name': 'Princess Garden Of Mayfair',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zmKhu0P6idUlm8G14Q9B-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/princess-garden-of-mayfair-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 51,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512773, 'longitude': -0.153083},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '8-10 N Audley Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 6ZD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8-10 N Audley Street',
#      'London W1K 6ZD',
#      'United Kingdom']},
#    'phone': '+442074933223',
#    'display_phone': '+44 20 7493 3223',
#    'distance': 1190.7587274700359},
#   {'id': 'eMqkAjMsvsqjZEwuVwh2dA',
#    'alias': 'lotus-london',
#    'name': 'Lotus',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6-YG5gxUwQqB_MVryDnxYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lotus-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 61,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4970261273306,
#     'longitude': -0.0161981516153809},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '9 Oakland Quay',
#     'address2': 'Inner Millwall Dock',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E14 9EA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Oakland Quay',
#      'Inner Millwall Dock',
#      'London E14 9EA',
#      'United Kingdom']},
#    'phone': '+442075156445',
#    'display_phone': '+44 20 7515 6445',
#    'distance': 8473.138078439868},
#   {'id': 'IeMFeX8iu-C1gYaM-sZteA',
#    'alias': 'yipin-china-restaurant-london',
#    'name': 'Yipin China Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/im88zV5X2dPNzEo9Bf-mDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yipin-china-restaurant-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 34,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.537275, 'longitude': -0.106626},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '70-72 Liverpool Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 0QD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['70-72 Liverpool Road',
#      'London N1 0QD',
#      'United Kingdom']},
#    'phone': '+442073543388',
#    'display_phone': '+44 20 7354 3388',
#    'distance': 3391.102734013863},
#   {'id': 'Ame6cZG8I-DQ5tkMtdyyeg',
#    'alias': 'good-earth-london-2',
#    'name': 'Good Earth',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_A_cE9_3q_I-Ci25eZGGtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/good-earth-london-2?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 39,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4968451, 'longitude': -0.1684174},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '233 Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 2EP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['233 Brompton Road',
#      'London SW3 2EP',
#      'United Kingdom']},
#    'phone': '+442075843658',
#    'display_phone': '+44 20 7584 3658',
#    'distance': 2867.1408887047874},
#   {'id': 'z0VuLvFLvGjKgF30mM_kYw',
#    'alias': 'ping-pong-london-36',
#    'name': 'Ping Pong',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CoG6lhmaz0L8iWMmGT1wAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ping-pong-london-36?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 75,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5086555480957,
#     'longitude': -0.0736019983887672},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "3 St Katharine's Way",
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E1W 1BA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["3 St Katharine's Way",
#      'London E1W 1BA',
#      'United Kingdom']},
#    'phone': '+442076807850',
#    'display_phone': '+44 20 7680 7850',
#    'distance': 4382.845724584944},
#   {'id': 'UG46BO-eDyaKPUVGOtgYNw',
#    'alias': 'a-wong-london',
#    'name': 'A. Wong',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6pLMa3TXyzDXhsORF-fogA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/a-wong-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 47,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4930394, 'longitude': -0.1406692},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '70-71 Wilton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1DE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['70-71 Wilton Road',
#      'London SW1V 1DE',
#      'United Kingdom']},
#    'phone': '+442078288931',
#    'display_phone': '+44 20 7828 8931',
#    'distance': 2230.534863152845},
#   {'id': 'R6wtvD4TqQsDFi2D0oilPg',
#    'alias': 'kai-of-mayfair-london',
#    'name': 'Kai Of Mayfair',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uEMVsFL-nrYAixnPwA_SRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kai-of-mayfair-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 36,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.50875, 'longitude': -0.151732},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '65 S Audley Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 2QU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['65 S Audley Street',
#      'London W1K 2QU',
#      'United Kingdom']},
#    'phone': '+442074938988',
#    'display_phone': '+44 20 7493 8988',
#    'distance': 1170.6555568486363},
#   {'id': 'BuFA-nSzJxJcG1ZWEj4AYw',
#    'alias': 'pearl-liang-london',
#    'name': 'Pearl Liang',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oJXKFlwrJcomFFoR3RWaJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pearl-liang-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 84,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5192622106976,
#     'longitude': -0.181188583374023},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '8 Sheldon Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 6EZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Sheldon Square',
#      'London W2 6EZ',
#      'United Kingdom']},
#    'phone': '+442072897000',
#    'display_phone': '+44 20 7289 7000',
#    'distance': 3210.4704169144943},
#   {'id': 'y9MWERu8ULGHhMKaDn8F2Q',
#    'alias': 'firecracker-london',
#    'name': 'Firecracker',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LDmgSAH6aYigccBqn5EkiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/firecracker-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 41,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'karaoke', 'title': 'Karaoke'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4949849, 'longitude': -0.1271241},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '44 Horseferry Road',
#     'address2': 'Westminster',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1P 2AF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['44 Horseferry Road',
#      'Westminster',
#      'London SW1P 2AF',
#      'United Kingdom']},
#    'phone': '+442072224680',
#    'display_phone': '+44 20 7222 4680',
#    'distance': 2089.3863287375334},
#   {'id': '6yqhDUickUwxIwaIticYOg',
#    'alias': 'four-seasons-london',
#    'name': 'Four Seasons',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uBTQDUKcP3yrkHnzh2f5LQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/four-seasons-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 100,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5130037, 'longitude': -0.1874014},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '84 Queensway',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 3RL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['84 Queensway', 'London W2 3RL', 'United Kingdom']},
#    'phone': '+442072294320',
#    'display_phone': '+44 20 7229 4320',
#    'distance': 3558.211280376721},
#   {'id': 'uaWX6Rlt91KbJvFOEr2_DA',
#    'alias': 'yming-london',
#    'name': 'Yming',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GW_e9wqnGLkdoxMkAeftyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yming-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 32,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51298, 'longitude': -0.130376},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '35-36 Greek Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 5DL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['35-36 Greek Street',
#      'London W1D 5DL',
#      'United Kingdom']},
#    'phone': '+442077342721',
#    'display_phone': '+44 20 7734 2721',
#    'distance': 390.3300443859922},
#   {'id': 'M2sGFRvTvozQ5Z3bw6JPjQ',
#    'alias': 'ma-la-london',
#    'name': 'Ma La',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WagdFT5JHxKWQT-NatdrZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ma-la-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 24,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4967879034045,
#     'longitude': -0.131008437607831},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '37 Monck Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1P 2BL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['37 Monck Street',
#      'London SW1P 2BL',
#      'United Kingdom']},
#    'phone': '+442072222218',
#    'display_phone': '+44 20 7222 2218',
#    'distance': 1816.9696172196484},
#   {'id': '7pwy404wcQGvGzM9RjxWdQ',
#    'alias': 'wong-kei-restaurant-london',
#    'name': 'Wong Kei Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FRS766QUY4JPHIC8Hpi44A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wong-kei-restaurant-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 195,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5115375, 'longitude': -0.132421},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '41-43 Wardour Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 6PY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['41-43 Wardour Street',
#      'London W1D 6PY',
#      'United Kingdom']},
#    'phone': '+442074378408',
#    'display_phone': '+44 20 7437 8408',
#    'distance': 289.13121319043125},
#   {'id': 'lfUDW3AFKicfSZivkYVKBA',
#    'alias': 'ping-pong-london-32',
#    'name': 'Ping Pong',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WGm8kZfQIplRb_lOW5CSyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ping-pong-london-32?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 72,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'tea', 'title': 'Tea Rooms'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5153116, 'longitude': -0.150888},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '29 A James Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 1DZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['29 A James Street',
#      'London W1U 1DZ',
#      'United Kingdom']},
#    'phone': '+442070343100',
#    'display_phone': '+44 20 7034 3100',
#    'distance': 1069.3451404139034},
#   {'id': 'CJkYOQLygyT9k3vl3mmG5w',
#    'alias': 'taiwan-village-london',
#    'name': 'Taiwan Village',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UTqWt54x-wDPFqaURBVi2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taiwan-village-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 16,
#    'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4855449, 'longitude': -0.2020701},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '85 Lillie Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 1UD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['85 Lillie Road', 'London SW6 1UD', 'United Kingdom']},
#    'phone': '+442073812900',
#    'display_phone': '+44 20 7381 2900',
#    'distance': 5491.206323167088},
#   {'id': 'vjbJN0mucBjlddFt1Ka22g',
#    'alias': 'green-cottage-london',
#    'name': 'Green Cottage',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Pd3HqisfyKcExtsMen-TeA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/green-cottage-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 21,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5458012795971,
#     'longitude': -0.176575183868408},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '9 New College Parade',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 5EP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 New College Parade',
#      'London NW3 5EP',
#      'United Kingdom']},
#    'phone': '+442077227892',
#    'display_phone': '+44 20 7722 7892',
#    'distance': 4618.6795485167295},
#   {'id': 'GkX3yV3ggecmmemw7MhS9Q',
#    'alias': 'dong-phuong-london',
#    'name': 'Dong Phuong',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3T8k9FYdVMPP-d4qfrIR7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dong-phuong-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 6,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.453886, 'longitude': -0.245483},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '32 Roehampton High Street',
#     'address2': 'Roehampton',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW15 4HJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['32 Roehampton High Street',
#      'Roehampton',
#      'London SW15 4HJ',
#      'United Kingdom']},
#    'phone': '+442087883888',
#    'display_phone': '+44 20 8788 3888',
#    'distance': 10024.358410964413},
#   {'id': '2G0a1v9ubpNO_wADUVgs3A',
#    'alias': 'yauatcha-city-london',
#    'name': 'Yauatcha City',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oRQcKVOkrAdU2qBZbvJxwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yauatcha-city-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 33,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5188478034811,
#     'longitude': -0.0844600399504998},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '2 Broadgate Circle',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2M 7UR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Broadgate Circle',
#      'London EC2M 7UR',
#      'United Kingdom']},
#    'phone': '+442038179888',
#    'display_phone': '+44 20 3817 9888',
#    'distance': 3625.489644058402},
#   {'id': '7LMRibjYvu1I0vuxU5taPg',
#    'alias': 'new-culture-revolution-london-2',
#    'name': 'New Culture Revolution',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nP-28DkZIAMA77ydHmytbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-culture-revolution-london-2?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 29,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.484645, 'longitude': -0.174931},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '305 Kings Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 5EP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['305 Kings Road', 'London SW3 5EP', 'United Kingdom']},
#    'phone': '+442073529281',
#    'display_phone': '+44 20 7352 9281',
#    'distance': 4133.66614069431},
#   {'id': 'neMkWvqA_HOCzo2fvoI3sw',
#    'alias': 'royal-china-london-7',
#    'name': 'Royal China',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bQ67GzjP9zCMHfznxX7u_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/royal-china-london-7?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 75,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5055789413133,
#     'longitude': -0.0280016434014305},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '30 Westferry Circus',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E14 8RR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['30 Westferry Circus',
#      'London E14 8RR',
#      'United Kingdom']},
#    'phone': '+442077190888',
#    'display_phone': '+44 20 7719 0888',
#    'distance': 7514.566037591502},
#   {'id': 'r6e1riScojLlPMhn2kK1Jw',
#    'alias': 'mandarin-kitchen-london-2',
#    'name': 'Mandarin Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/arQZ6v9PEjTqLhFz_Y7d4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mandarin-kitchen-london-2?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 41,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.510816, 'longitude': -0.186891},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14-16 Queensway',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 3RX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14-16 Queensway', 'London W2 3RX', 'United Kingdom']},
#    'phone': '+442077279012',
#    'display_phone': '+44 20 7727 9012',
#    'distance': 3531.9846996809965},
#   {'id': 'mDUKapRhtOIpTFczScuvRg',
#    'alias': 'baiwei-london',
#    'name': 'Baiwei',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wZGTQQ_E9T7e-J8x06E5bw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baiwei-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 54,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5117895, 'longitude': -0.1291729},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '8 Little Newport Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 7JJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Little Newport Street',
#      'London WC2H 7JJ',
#      'United Kingdom']},
#    'phone': '+442074943605',
#    'display_phone': '+44 20 7494 3605',
#    'distance': 483.5849731601068},
#   {'id': 'GHAsS9cIM23hqoCol53KRA',
#    'alias': 'hutong-london',
#    'name': 'Hutong',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0CvGPblswZK9Qs-m21Gj6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hutong-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 81,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5042658217118,
#     'longitude': -0.0863956051376916},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Level 33',
#     'address2': 'The Shard',
#     'address3': '31 St Thomas Street',
#     'city': 'London',
#     'zip_code': 'SE1 9RY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Level 33',
#      'The Shard',
#      '31 St Thomas Street',
#      'London SE1 9RY',
#      'United Kingdom']},
#    'phone': '+442030111257',
#    'display_phone': '+44 20 3011 1257',
#    'distance': 3559.8414471826172},
#   {'id': 'IYim7exMsSWVWHnU-BvGfA',
#    'alias': 'shikumen-shepherds-bush-london',
#    'name': "Shikumen Shepherd's Bush",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7SQqfWIi3U6yZBo9kFE-rw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shikumen-shepherds-bush-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 17,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5040114224861,
#     'longitude': -0.224605244444547},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Dorsett Hotel',
#     'address2': "58 Shepherd's Bush Green",
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W12 8QE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Dorsett Hotel',
#      "58 Shepherd's Bush Green",
#      'London W12 8QE',
#      'United Kingdom']},
#    'phone': '+442087499978',
#    'display_phone': '+44 20 8749 9978',
#    'distance': 6213.178906782448},
#   {'id': 'cxpKr3MfJKvpR77DR1JdIA',
#    'alias': 'orient-london-london',
#    'name': 'Orient London',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oIX0H3FzqjO3rau8j5Qj8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/orient-london-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 30,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5108757019043,
#     'longitude': -0.131764858961105},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '15 Wardour Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 6PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Wardour Street',
#      'London W1D 6PH',
#      'United Kingdom']},
#    'phone': '+442079898880',
#    'display_phone': '+44 20 7989 8880',
#    'distance': 350.3245996866791},
#   {'id': 'fknsE8zZ0_sP-n35Z4RRKw',
#    'alias': 'new-city-london',
#    'name': 'New City',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rbRdPLHUTjGWqjFR56PRXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-city-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 8,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.475829, 'longitude': -0.14893},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '183-185 Battersea Park Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW11 4LB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['183-185 Battersea Park Road',
#      'London SW11 4LB',
#      'United Kingdom']},
#    'phone': '+442077209928',
#    'display_phone': '+44 20 7720 9928',
#    'distance': 4216.931901325764},
#   {'id': 'CpfJcfFlQdgqA4qjH02uBA',
#    'alias': 'hiro-london',
#    'name': 'Hiro',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gX997jxzinVc-fvEuBhvig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hiro-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 11,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5377, 'longitude': -0.184907},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '100 Boundary Road',
#     'address2': "Saint John's Wood",
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW8 0RH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['100 Boundary Road',
#      "Saint John's Wood",
#      'London NW8 0RH',
#      'United Kingdom']},
#    'phone': '+442073726720',
#    'display_phone': '+44 20 7372 6720',
#    'distance': 4371.8172739795555},
#   {'id': '-50FYxMbPA_qVyv6uVfqsQ',
#    'alias': 'royal-china-london-4',
#    'name': 'Royal China',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/naV7h48Qt-PGHdjLcuySsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/royal-china-london-4?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 72,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5178304458283,
#     'longitude': -0.155250194816181},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '24-26 Baker Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 3BZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24-26 Baker Street',
#      'London W1U 3BZ',
#      'United Kingdom']},
#    'phone': '+442074874688',
#    'display_phone': '+44 20 7487 4688',
#    'distance': 1446.0336151092515},
#   {'id': 'Gag-sVfJ3DpEiYvBvgm8Uw',
#    'alias': 'mamalan-london-5',
#    'name': 'Mamalan',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OvxVUiavE_N6bqL_qzVEug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mamalan-london-5?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 25,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4624237690863,
#     'longitude': -0.111667388978524},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Unit 18 Brixton Village',
#     'address2': 'Coldharbour Lane',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW9 8PR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 18 Brixton Village',
#      'Coldharbour Lane',
#      'London SW9 8PR',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5852.354882052575},
#   {'id': 'S3KrbezyEy4hR3K6JYMrJA',
#    'alias': 'murger-han-london-3',
#    'name': 'Murger Han',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zZ_2Ry6e9zo_CbQVhrL6OQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/murger-han-london-3?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 10,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.50933, 'longitude': -0.13797},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '8A Sackville street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 3DF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8A Sackville street',
#      'London W1S 3DF',
#      'United Kingdom']},
#    'phone': '+442077340300',
#    'display_phone': '+44 20 7734 0300',
#    'distance': 407.97324803935334},
#   {'id': 'BCfxB_m7EMpDCz5Ei-i8yQ',
#    'alias': 'la-mian-and-dim-sum-stall-london',
#    'name': 'La Mian & Dim Sum Stall',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mlEwb0Ynezfg62z4j1amgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-mian-and-dim-sum-stall-london?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ',
#    'review_count': 6,
#    'categories': [{'alias': 'streetvendors', 'title': 'Street Vendors'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5227498599062,
#     'longitude': -0.0716686248779297},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Brick Lane Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE10 9HY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Brick Lane Market',
#      'London SE10 9HY',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4582.819407920872}],
#  'total': 1200,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %% [markdown]
# Whoops, what's going on here!? Well, notice from our previous preview of the response that we saw there were a hierarhcy within the response. Let's begin to investigate further to see what the problem is.
#
# First, recall that the overall strucutre of the response was a dictionary. Let's look at what the keys are:

# %%
response.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %% [markdown]
# Consult the Yelp API and learn what value is carried in each key.
#
# #### Continue to preview these keys  further to get a little better acquainted.

# %%
print('BUSINESS:', response['businesses'][0])
print()
print('REGION:', response['region'])
print()
print('TOTAL :',response['total'])
# Out:
# BUSINESS: {'id': 'h2cCoDNQOPd51HFwvuAGNg', 'alias': 'hakkasan-london-3', 'name': 'Hakkasan', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IcS9yzJnweDO4DsfJ94jAw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/hakkasan-london-3?adjust_creative=daXmVQtyzQNoOXYDAOOHmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=daXmVQtyzQNoOXYDAOOHmQ', 'review_count': 218, 'categories': [{'alias': 'cantonese', 'title': 'Cantonese'}], 'rating': 4.0, 'coordinates': {'latitude': 51.5171482803943, 'longitude': -0.13180578932657}, 'transactions': [], 'price': '££££', 'location': {'address1': '8 Hanway Place', 'address2': '', 'address3': '', 'city': 'London', 'zip_code': 'W1T 1HD', 'country': 'GB', 'state': 'XGL', 'display_address': ['8 Hanway Place', 'London W1T 1HD', 'United Kingdom']}, 'phone': '+442079277000', 'display_phone': '+44 20 7927 7000', 'distance': 558.9650039747677}
#
# REGION: {'center': {'longitude': -0.135955810546875, 'latitude': 51.51283552118349}}
#
# TOTAL : 1200

# %% [markdown]
# This makes more sense, so we are mainly interested in the `businesses` for our needs.
#
# ### Print the names of businesses and included ratings

# %%
for business in response['businesses']:
    print("Name:",business['name'],",",'Rating:',business['rating'])
# Out:
# Name: Hakkasan , Rating: 4.0
# Name: Bamboo Flute , Rating: 4.5
# Name: Yauatcha , Rating: 4.0
# Name: Lanzhou Noodle Bar , Rating: 4.0
# Name: Hakkasan Mayfair , Rating: 4.0
# Name: Silk Road , Rating: 4.5
# Name: Hunan , Rating: 4.5
# Name: Barshu , Rating: 4.0
# Name: Bugis Street Brasserie , Rating: 4.0
# Name: Gold Mine , Rating: 4.0
# Name: Royal China , Rating: 4.0
# Name: Chi Noodle , Rating: 4.0
# Name: Joy King Lau , Rating: 4.0
# Name: Sichuan Folk , Rating: 4.0
# Name: Xi'an Impressions , Rating: 4.5
# Name: Dragon Castle , Rating: 4.0
# Name: Canton Element , Rating: 4.5
# Name: Bun House , Rating: 4.0
# Name: The Duck and Rice , Rating: 4.0
# Name: Princess Garden Of Mayfair , Rating: 4.0
# Name: Lotus , Rating: 4.0
# Name: Yipin China Restaurant , Rating: 4.0
# Name: Good Earth , Rating: 4.0
# Name: Ping Pong , Rating: 4.0
# Name: A. Wong , Rating: 4.0
# Name: Kai Of Mayfair , Rating: 4.0
# Name: Pearl Liang , Rating: 3.5
# Name: Firecracker , Rating: 4.0
# Name: Four Seasons , Rating: 3.5
# Name: Yming , Rating: 4.0
# Name: Ma La , Rating: 4.0
# Name: Wong Kei Restaurant , Rating: 3.5
# Name: Ping Pong , Rating: 3.5
# Name: Taiwan Village , Rating: 4.5
# Name: Green Cottage , Rating: 4.0
# Name: Dong Phuong , Rating: 5.0
# Name: Yauatcha City , Rating: 4.0
# Name: New Culture Revolution , Rating: 4.0
# Name: Royal China , Rating: 3.5
# Name: Mandarin Kitchen , Rating: 4.0
# Name: Baiwei , Rating: 3.5
# Name: Hutong , Rating: 3.5
# Name: Shikumen Shepherd's Bush , Rating: 4.0
# Name: Orient London , Rating: 4.0
# Name: New City , Rating: 4.5
# Name: Hiro , Rating: 4.5
# Name: Royal China , Rating: 3.5
# Name: Mamalan , Rating: 4.0
# Name: Murger Han , Rating: 4.5
# Name: La Mian & Dim Sum Stall , Rating: 5.0

# %% [markdown]
# Great, now are are getting somewhere. It is a good idea at this stage to store this information as a dataframe for processing further.
# ### Create a Pandas dataframe for contents of `businesses`
# * Check the number of records in the dataframe
# * Inspect the columns and head

# %%
import pandas as pd
df = pd.DataFrame(response['businesses'])
df.head()
# Out:
#                        alias  \
# 0          hakkasan-london-3
# 1     bamboo-flute-fitzrovia
# 2          yauatcha-london-7
# 3  lanzhou-noodle-bar-london
# 4  hakkasan-mayfair-london-2
#
#                                           categories  \
# 0     [{'alias': 'cantonese', 'title': 'Cantonese'}]
# 1         [{'alias': 'chinese', 'title': 'Chinese'}]
# 2  [{'alias': 'dimsum', 'title': 'Dim Sum'}, {'al...
# 3  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...
# 4         [{'alias': 'chinese', 'title': 'Chinese'}]
#
#                                          coordinates     display_phone  \
# 0  {'latitude': 51.5171482803943, 'longitude': -0...  +44 20 7927 7000
# 1  {'latitude': 51.5228746, 'longitude': -0.1418939}  +44 20 7387 2738
# 2  {'latitude': 51.5137076071076, 'longitude': -0...  +44 20 7494 8888
# 3  {'latitude': 51.5116034713013, 'longitude': -0...  +44 20 7467 4546
# 4  {'latitude': 51.5103202323384, 'longitude': -0...  +44 20 7907 1888
#
#       distance                      id  \
# 0   558.965004  h2cCoDNQOPd51HFwvuAGNg
# 1  1189.508255  QE5aa5N-dbfvafLsjn7TVg
# 2   112.598410  sYwBQ7mJYhB35nn-_SZstQ
# 3   578.474355  pdFiFtol9YI__9ROOXUIYA
# 4   681.445072  chEEcQbc8PbidTeXK34H9g
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/IcS9yz...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/kYQZjH...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/G7Ydt9...      False
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/IKy91e...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/LX_W20...      False
#
#                                             location                name  \
# 0  {'address1': '8 Hanway Place', 'address2': '',...            Hakkasan
# 1  {'address1': '145 Cleveland Street', 'address2...        Bamboo Flute
# 2  {'address1': '15-17 Broadwick Street', 'addres...            Yauatcha
# 3  {'address1': '33 Cranbourne Street', 'address2...  Lanzhou Noodle Bar
# 4  {'address1': '17 Bruton Street', 'address2': '...    Hakkasan Mayfair
#
#            phone price  rating  review_count transactions  \
# 0  +442079277000  ££££     4.0           218           []
# 1  +442073872738     £     4.5            28           []
# 2  +442074948888   £££     4.0           456           []
# 3  +442074674546     £     4.0           310           []
# 4  +442079071888  ££££     4.0           117           []
#
#                                                  url
# 0  https://www.yelp.com/biz/hakkasan-london-3?adj...
# 1  https://www.yelp.com/biz/bamboo-flute-fitzrovi...
# 2  https://www.yelp.com/biz/yauatcha-london-7?adj...
# 3  https://www.yelp.com/biz/lanzhou-noodle-bar-lo...
# 4  https://www.yelp.com/biz/hakkasan-mayfair-lond...

# %% [markdown]
# This is fantastic. We have successfully learned a new API , made requests to it, recieved and studied the response and stored the results in a dataframe and can now enjoy all the goodness of Pandas. Thats quite a bit of data engineering.
#
# ### Visualize the location from search query
# The `region` key in the response carries the geographical information for the region searched.
# * Get the latitude / longitude information from `region`
# * Create a folium map with these coordinates.
# * Use a zoom start value = 13

# %%
loc = response['region']['center']
# Out:
# -0.13180578932657

# %%
# !pip install folium
import folium
m =folium.Map([loc['latitude'],loc['longitude']],zoom_start=13)
m
# Out:
# Requirement already satisfied: folium in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (0.7.0)
# Requirement already satisfied: six in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (from folium) (1.11.0)
# Requirement already satisfied: branca>=0.3.0 in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (from folium) (0.3.1)
# Requirement already satisfied: numpy in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (from folium) (1.15.1)
# Requirement already satisfied: jinja2 in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (from folium) (2.10)
# Requirement already satisfied: requests in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (from folium) (2.19.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (from jinja2->folium) (1.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (from requests->folium) (2018.8.24)
# Requirement already satisfied: idna<2.8,>=2.5 in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (from requests->folium) (2.7)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (from requests->folium) (1.23)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Expected Output:
# ![](london.png)

# %% [markdown]
# Nice. We can now extract the coordinate information for each business and plot it on this map.
#
# ### Get the business coordinates from dataframe for each business and plot on the map above

# %%
for location in df['coordinates']:

    long = location['longitude']
    lat = location['latitude']
    
    marker = folium.Marker(location=[lat,long])
    marker.add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Expected output:
# ![](markers.png)

# %% [markdown]
# Kool so we have everything in place but the visualization is still not very *Informative* so to speak. You can't tell which marker represents which business and also other information on business like rating, cost, links to user reviews etc. is still not visible. SO its geographical , but not exactly an Information System yet as you cant make any decisions on this information.  Here's as example of what it possible can look like
# ![](out.png)

# %% [markdown]
# For this you need to understand `folium.popup()` which let's you click on a marker to show a pop up window. This window acts more like an HTML page so you can easily format the information you present in the popup using following values:
# * The official business logo/image:  `image_url`
# * Name of the Business: `name`
# * Price (how expensive): `price`
# * Links to user reviews on Yelp: `url`
#
# Doing this in HTML is not required , so we recommend that you first try to put in basic information in the popups as just text. As a next stage , you can start changing into HTML code to make it visually more appealing.
#
# ### Attempt to recreate the interactive visualization shown above.
#
# Here's a good resource with code examples on [how to create folium popups](https://github.com/python-visualization/folium/blob/master/examples/Popups.ipynb)

# %%
from folium import IFrame

# %% [markdown]
# Wow . An Interactive Geographical information System backed by live data through API calling.
#
# <img src="star.jpg" width=300>
#
# ### More APIs to Checkout
#
# * Google Maps
# * Twitter
# * AWS
# * IBM's Watson
# * Yelp

# %% [markdown]
# ## Summary
#
# In this lab, we learned how to use the Yelp API with authentication, making calls, understanding the responses and creating interactive geographical visualizations in Folium. We encourage you to re-visit this lab again once you have studied some important machine learning algorithms to make predictions , find similarities, group/cluster businesses or classify them based on user criteria.
